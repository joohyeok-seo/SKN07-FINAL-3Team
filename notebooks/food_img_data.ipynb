# %%
import pandas as pd

# %%
food = pd.read_csv('./data/food.csv')
food
# Out:
#           식품명     대분류       소분류    기준량  에너지(kcal)  탄수화물(g)  단백질(g)  지방(g)  \
# 0        고추잡채   메인 반찬       볶음류  100ml       69.0     4.27    4.19   4.01
# 1       고추장볶음   메인 반찬       볶음류  100ml      396.0    34.64    9.54  25.57
# 2    고추장아찌 무침  서브 반찬2    생채·무침류  100ml       62.0    13.91    1.54   0.90
# 3       고등어찌개       국  찌개 및 전골류  100ml       38.0     2.02    3.50   1.69
# 4        고등어찜   메인 반찬        찜류  100ml       92.0     3.21    8.57   4.88
# ..        ...     ...       ...    ...        ...      ...     ...    ...
# 547   홍합 소고기죽       국   죽 및 스프류  100ml      130.0    17.83    6.16   3.33
# 548  홍합국(홍합탕)       국    국 및 탕류  100ml       17.0     0.75    2.81   0.24
# 549       회덮밥       밥        밥류  100ml       79.0    14.17    3.81   0.58
# 550       흑미밥       밥        밥류  100ml      119.0    25.63    2.25   0.37
# 551        흰죽       국   죽 및 스프류  100ml       64.0    13.49    1.17   0.28
#
#      당류(g)  식이섬유(g)  나트륨(mg)   식품중량
# 0     1.51      1.6    160.0  400.0
# 1    14.29      3.6   1670.0   54.0
# 2     4.80      3.1    697.0   37.0
# 3     0.90      0.5    193.0  451.0
# 4     1.02      1.4    159.0  191.0
# ..     ...      ...      ...    ...
# 547   0.71      0.8    127.0  225.0
# 548   0.04      0.0    137.0  300.0
# 549   1.54      0.6     66.0  698.0
# 550   0.18      0.8      1.0  390.0
# 551   0.09      0.3    130.0  291.0
#
# [552 rows x 12 columns]

# %%
# 식품명 list 로 변환
food_names = food['식품명'].tolist()
food_names
# Out:
# ['고추잡채',
#  '고추장볶음',
#  '고추장아찌 무침',
#  '고등어찌개',
#  '고등어찜',
#  '고등어튀김',
#  '고디국(다슬기맑은국)',
#  '고사리나물',
#  '고등어구이',
#  '고등어조림',
#  '고구마튀김',
#  '고기만두',
#  '고구마밥',
#  '고구마줄기나물',
#  '계란빵',
#  '고구마맛탕',
#  '게맛살튀김',
#  '게조림',
#  '겨자채',
#  '검정콩밥',
#  '강낭콩밥',
#  '건새우 미역국',
#  '건새우볶음',
#  '감자탕',
#  '감자튀김',
#  '곰탕',
#  '곤드레밥',
#  '곤약조림',
#  '골뱅이무침',
#  '고추조림',
#  '고추튀김',
#  '고춧잎나물',
#  '기장밥',
#  '근대 된장국',
#  '근대나물',
#  '굴비구이',
#  '굴전',
#  '군만두',
#  '굴 미역국',
#  '굴국',
#  '과일샐러드',
#  '광어 매운탕',
#  '김치볶음',
#  '김치국',
#  '김치만두',
#  '김치 고기만두',
#  '김치 돼지고기볶음',
#  '김치 된장국',
#  '김치 청국장찌개',
#  '김치 콩나물국',
#  '김밥',
#  '김부각',
#  '김말이튀김',
#  '꽈리고추찜',
#  '낙지 덮밥',
#  '꽃게장',
#  '꽃게탕',
#  '꽈리고추볶음',
#  '꽁치구이',
#  '꽁치조림',
#  '꽁치튀김',
#  '꼬리곰탕',
#  '꼬막찜',
#  '깻잎장아찌',
#  '깻잎전',
#  '깻잎찜',
#  '껍질콩볶음',
#  '깻잎김치',
#  '깻잎나물',
#  '김치찜',
#  '깐풍기',
#  '김치찌개',
#  '김치순두부',
#  '김치전',
#  '달걀부침(달걀후라이)',
#  '달걀조림',
#  '달걀찜',
#  '달걀말이',
#  '단호박조림',
#  '달걀 샐러드',
#  '달걀국',
#  '다시마무침',
#  '다시마튀각',
#  '단무지무침',
#  '느타리버섯볶음',
#  '느타리버섯튀김',
#  '녹두빈대떡',
#  '냉이 된장국',
#  '냉이초나물',
#  '넙치구이',
#  '노각무침',
#  '난자완스',
#  '낙지 비빔밥',
#  '낙지무침',
#  '낙지볶음',
#  '닭찜',
#  '닭튀김',
#  '닭튀김 샐러드',
#  '닭죽',
#  '닭볶음(닭갈비)',
#  '닭조림',
#  '닭도리탕',
#  '닭백숙',
#  '닭날개구이',
#  '닭다리구이',
#  '닭다리조림',
#  '닭고기 탕수',
#  '닭고기냉채',
#  '닭고기육개장',
#  '닭곰탕',
#  '닭구이',
#  '닭가슴살 샐러드',
#  '닭강정',
#  '닭고기 덮밥',
#  '닭고기 미역국',
#  '닭고기 샐러드',
#  '달걀후라이',
#  '달래무침',
#  '대합 미역국',
#  '대합죽',
#  '대구 매운탕',
#  '대구지리',
#  '대구찜',
#  '도토리묵무침',
#  '돈가스',
#  '도라지생채',
#  '도루묵조림',
#  '도라지나물',
#  '된장국',
#  '돼지사태찜',
#  '돼지등심 장조림',
#  '돼지머리국밥',
#  '돼지불고기',
#  '돼지고기볶음',
#  '돼지고기찌개',
#  '돼지고기 장조림',
#  '돼지고기강정',
#  '돼지갈비찜',
#  '돼지고기 꼬치구이',
#  '돼지고기 스테이크',
#  '동태튀김',
#  '돼지갈비구이',
#  '동태전',
#  '동태조림',
#  '동태찌개',
#  '동태찜',
#  '돌나물',
#  '돌나물무침',
#  '돌솥 비빔밥',
#  '동태 매운탕',
#  '동태국',
#  '떡국',
#  '땅콩조림',
#  '땅콩죽',
#  '두부찌개',
#  '두부튀김',
#  '들깨국',
#  '들깨죽',
#  '두부전',
#  '두부조림',
#  '두부냉채',
#  '두부볶음',
#  '두부부침',
#  '두부 된장국',
#  '두부 청국장찌개',
#  '두부국',
#  '두부김치',
#  '된장찌개',
#  '두부 달걀찜',
#  '떡볶이',
#  '떡산적',
#  '떡만두국',
#  '런천미트구이',
#  '라볶이',
#  '마카로니 샐러드',
#  '마늘쫑볶음',
#  '마늘쫑장아찌무침',
#  '마늘쫑무침',
#  '멸치볶음',
#  '멸치조림',
#  '멕시컨샐러드',
#  '멸치 미역국',
#  '메밀묵국',
#  '메추리알 돼지고기장조림',
#  '메추리알 어묵조림',
#  '메추리알장조림',
#  '메밀묵 무침',
#  '머위나물',
#  '만두탕수',
#  '맛살전',
#  '망둥어찜',
#  '매운 어묵볶음',
#  '만두국',
#  '마파두부',
#  '미나리나물',
#  '미나리무침',
#  '미소된장국',
#  '물만두',
#  '미나리 초무침',
#  '묵밥',
#  '무생채',
#  '무조림',
#  '무생채(무만)',
#  '무국',
#  '무나물',
#  '무말랭이무침',
#  '무 어묵조림',
#  '무 파래무침',
#  '무 된장국',
#  '무 북어국',
#  '모듬 초밥',
#  '모듬배추나물',
#  '모듬버섯볶음',
#  '미트볼조림',
#  '미역냉국',
#  '미역줄기볶음',
#  '미역초무침',
#  '미역튀각',
#  '미역국',
#  '미역 오이무침',
#  '배추 겉절이',
#  '배추 된장국',
#  '배추국',
#  '바지락국',
#  '바지락찜',
#  '방풍나물',
#  '바지락 미역국',
#  '배추전',
#  '배추나물',
#  '버섯찌개',
#  '버섯전',
#  '버섯 매운탕',
#  '버섯국',
#  '볶음밥',
#  '부대찌개',
#  '보리밥',
#  '베이컨떡말이구이',
#  '베이컨채소볶음',
#  '병어조림',
#  '비빔밥',
#  '브로콜리무침',
#  '비름나물',
#  '불낙전골',
#  '브로콜리 두부무침',
#  '브로콜리 버섯볶음',
#  '북어국',
#  '북어채 고추장 무침',
#  '북어강정',
#  '북어구이',
#  '부추무침',
#  '부추잡채',
#  '부추전',
#  '부추 겉절이',
#  '부추김치',
#  '부추나물',
#  '뼈다귀해장국',
#  '사골국',
#  '새우탕',
#  '새우튀김',
#  '새우 탕수',
#  '새우무침',
#  '새우전',
#  '새우젓국',
#  '상추겉절이',
#  '새송이버섯볶음',
#  '새싹 샐러드',
#  '삼치구이',
#  '삼치조림',
#  '삼치튀김',
#  '상추 겉절이',
#  '삼겹살볶음',
#  '삼계탕',
#  '삼색 오이냉국',
#  '삼색냉채',
#  '삼치 양념구이',
#  '삶은 땅콩 조림',
#  '삼각김밥',
#  '소갈비찜',
#  '소고기 국밥',
#  '소고기 덮밥',
#  '소고기 두부국',
#  '소고기 미역국',
#  '선짓국',
#  '설렁탕',
#  '세발낙지볶음',
#  '소갈비 구이',
#  '섞어찌개(모듬찌개)',
#  '생선까스',
#  '샐러드',
#  '소시지튀김',
#  '소시지 케첩볶음',
#  '소시지볶음',
#  '소시지조림',
#  '소불고기',
#  '소사태찜',
#  '소등심구이',
#  '소라무침',
#  '소고기채소볶음',
#  '소등심 스테이크',
#  '소고기볶음',
#  '소고기육개장',
#  '소고기찜',
#  '소고기 샌드위치',
#  '소고기 완자전',
#  '소고기 장조림',
#  '순대볶음',
#  '순대',
#  '순대국',
#  '숙주나물',
#  '숙주미나리나물',
#  '수수밥',
#  '스크램블드에그',
#  '쑥갓나물',
#  '쑥갓오이무침',
#  '쑥튀김',
#  '시금치나물',
#  '시래기 된장국',
#  '시래기나물',
#  '시금치 겉절이',
#  '시금치 된장국',
#  '아귀 매운탕',
#  '아귀찜',
#  '아욱 된장국',
#  '애호박 감자된장국',
#  '애호박 된장국',
#  '애호박나물',
#  '알밥',
#  '얼갈이겉절이',
#  '어묵탕',
#  '어묵튀김',
#  '얼갈이 나물',
#  '얼갈이 된장국',
#  '어묵잡채',
#  '어묵조림',
#  '어묵국(어묵탕)',
#  '어묵볶음',
#  '어묵 감자볶음',
#  '어묵 매운탕',
#  '어묵 오이무침',
#  '어묵국',
#  '양송이버섯볶음',
#  '양장피',
#  '양파볶음',
#  '양배추 샐러드',
#  '양배추 초나물',
#  '양배추부추무침',
#  '양상추 샐러드',
#  '양념 오징어젓',
#  '양미리조림',
#  '양배추 겉절이',
#  '양배추 사과 샐러드',
#  '양념 돼지고기튀김',
#  '애호박부침개',
#  '애호박전',
#  '애호박찌개',
#  '애호박찜',
#  '연근전',
#  '연근조림',
#  '연근튀김',
#  '오징어볶음',
#  '오징어불고기',
#  '오징어 덮밥',
#  '오징어국',
#  '오징어무침',
#  '오이생채',
#  '오이소박이',
#  '오이장아찌',
#  '오이지무침',
#  '오이나물',
#  '오이냉국',
#  '오이무침',
#  '오이 도라지 생채',
#  '오이 미역냉국',
#  '오이고추 된장무침',
#  '오이김치',
#  '오리탕',
#  '오므라이스',
#  '오곡밥',
#  '오리 간장불고기',
#  '오리고기로스',
#  '오리백숙',
#  '열무나물',
#  '영양돌솥밥',
#  '연두부찜',
#  '연어구이',
#  '열무 된장국',
#  '열무 비빔밥',
#  '올갱이해장국',
#  '옥수수밥',
#  '옥수수부침',
#  '옥수수샐러드',
#  '오징어채볶음',
#  '오징어탕수',
#  '오징어튀김',
#  '오징어조림',
#  '오징어찌개',
#  '오징어채무침',
#  '유부 된장국',
#  '유부 초밥',
#  '유부조림',
#  '우엉조림',
#  '우럭구이',
#  '우엉볶음',
#  '완두콩밥',
#  '완자전',
#  '완자조림',
#  '잔멸치볶음',
#  '임연수구이',
#  '임연수조림',
#  '임연수튀김',
#  '육개장',
#  '율무밥',
#  '유채나물',
#  '유채무침',
#  '조기찜',
#  '조기튀김',
#  '조미 김구이',
#  '주먹밥',
#  '조기 양념구이',
#  '조기 오븐구이',
#  '조기구이',
#  '조기찌개',
#  '제육볶음',
#  '조개 미역국',
#  '적어구이',
#  '전복죽',
#  '제육(돼지고기 수육)',
#  '장조림',
#  '재첩국',
#  '장어 양념구이',
#  '장어매운탕',
#  '잡채밥',
#  '잡곡밥',
#  '잡곡죽',
#  '잡채',
#  '청포묵 무침',
#  '청포묵무침',
#  '채소튀김',
#  '천사채무침',
#  '청국장찌개',
#  '채소밥',
#  '채소전',
#  '채소죽',
#  '참치강정',
#  '참치구이',
#  '참치죽',
#  '참치찌개',
#  '참나물 겉절이',
#  '참나물 무침',
#  '참나물겉절이',
#  '참치 미역국',
#  '참치 샐러드',
#  '참나물',
#  '차조밥',
#  '짬뽕밥',
#  '짜사이무침',
#  '짜장밥',
#  '죽순볶음',
#  '쥐포무침',
#  '쥐포조림',
#  '치커리 겉절이',
#  '치커리겉절이',
#  '치킨데리야끼',
#  '취나물무침',
#  '추어탕',
#  '취나물',
#  '카레라이스',
#  '콩나물국',
#  '콩나물 느타리무침',
#  '콩나물 된장국',
#  '콩나물 선짓국',
#  '콩나물 황태국',
#  '콘치즈구이',
#  '콩나물 국밥',
#  '코다리조림',
#  '코다리찜',
#  '콩조림',
#  '콩나물밥',
#  '콩나물잡채',
#  '콩비지찌개',
#  '콩나물무침',
#  '콩나물냉채',
#  '파래무침',
#  '파래볶음',
#  '파무침',
#  '탕평채',
#  '토란국',
#  '탕수어',
#  '탕수육',
#  '풋마늘무침',
#  '표고버섯볶음',
#  '풋고추된장무침',
#  '팥죽',
#  '팥밥',
#  '파전',
#  '팔보채',
#  '피자',
#  '가오리회무침',
#  '가자미 매운탕',
#  '가자미구이',
#  '가자미조림',
#  '가자미찜',
#  '가자미튀김',
#  '가지나물',
#  '가지냉국',
#  '가지전',
#  '가지탕수',
#  '갈비탕',
#  '갈치구이',
#  '갈치조림',
#  '갈치찌개',
#  '갈치튀김',
#  '감자 된장국',
#  '감자 호박된장국',
#  '감자구이',
#  '감자국',
#  '감자밥',
#  '감자볶음',
#  '감자샐러드',
#  '감자샐러드 샌드위치',
#  '감자스프',
#  '감자연근튀김',
#  '감자전',
#  '감자조림',
#  '하이라이스',
#  '함박스테이크',
#  '해물 된장국',
#  '해물 완자전',
#  '해물볶음',
#  '해물콩나물찜',
#  '해물파전',
#  '해파리냉채',
#  '햄구이',
#  '햄버거',
#  '햄부침',
#  '햄샌드위치',
#  '햄샐러드',
#  '햄채소볶음',
#  '현미밥',
#  '호떡',
#  '호박 된장국',
#  '호박나물',
#  '호박죽',
#  '혼합잡곡밥',
#  '홍어회무침',
#  '홍합 무국',
#  '홍합 미역국',
#  '홍합 소고기죽',
#  '홍합국(홍합탕)',
#  '회덮밥',
#  '흑미밥',
#  '흰죽']

# %% [markdown]
# # Crawling

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.parse
from urllib.parse import unquote
from tqdm import tqdm
import os

# %% [markdown]
# img_url_dict = {}             # img_url을 저장할 딕셔너리
# fail_list = []                  # img_url 추출을 실패한 음식 리스트

# %% [markdown]
# # 이미지 저장 폴더가 없으면 생성
# if not os.path.exists("./food_image"):
#     os.makedirs("./food_image")

# %% [markdown]
# headers = {"User-Agent": "Mozilla/5.0"}

# %% [markdown]
# for food_name in tqdm(food_names, desc="food image download"):
#     # '네이버 음식백과'에 음식명 별 검색어 입력 url
#     url = f'https://terms.naver.com/search.naver?query={food_name}&dicType=15'
#     search = requests.get(url, headers=headers)
#     soup = BeautifulSoup(search.text, 'html.parser')
#     time.sleep(1)  # 검색 요청 후 딜레이 추가
#
#     # 상위 세 개의 content 링크 확인
#     for i in range(3):
#         try:
#             link_element = soup.find_all('ul', class_='content_list')[i] \
#                                .find('strong', class_='title') \
#                                .find('a')
#             link = link_element['href'] if link_element else None
#
#         except Exception as e:
#             # print(f"{food_name}{i}: {e}")
#             continue
#
#         detail_url = "https://terms.naver.com" + link
#         detail_res = requests.get(detail_url, headers=headers)
#         detail_soup = BeautifulSoup(detail_res.text, 'html.parser')
#         time.sleep(1)  # 상세 페이지 요청 후 딜레이 추가
#
#         # 개별 링크별 이미지 url 추출
#         img_tag = detail_soup.find('img')
#         if img_tag and img_tag.get('data-src'):
#             img_url = img_tag.get('data-src')
#             img_url_dic[food_name] = img_url
#
#             # 이미지 다운로드
#             urllib.request.urlretrieve(img_url, f"./food_image/{food_name}.jpg")
#             break                                 # img_url 발견 시 반복문 종료
#
#     else:
#         fail_list.append(food_name)

# %%
def food_image_downloader(food_list, download_folder):
    
    img_url_dict = {}             # img_url을 저장할 딕셔너리
    fail_list = []                  # img_url 추출을 실패한 음식 리스트

    # 이미지 저장 폴더가 없으면 생성
    if not os.path.exists(f"./{download_folder}"):
        os.makedirs(f"./{download_folder}")

    headers = {"User-Agent": "Mozilla/5.0"}
    
    for food_name in tqdm(food_list, desc="이미지 다운로드 진행중"):
        # '네이버 음식백과'에 음식명 별 검색어 입력 url
        url = f'https://terms.naver.com/search.naver?query={food_name}&dicType=15'
        search = requests.get(url, headers=headers)
        soup = BeautifulSoup(search.text, 'html.parser')
        time.sleep(1)  # 검색 요청 후 딜레이 추가
    
        # 상위 세 개의 content 링크 확인
        for i in range(3):
            try:
                link_element = soup.find_all('ul', class_='content_list')[i] \
                                   .find('strong', class_='title') \
                                   .find('a')
                link = link_element['href'] if link_element else None
                
            except Exception as e:
                # print(f"{food_name}{i}: {e}")
                continue
    
            detail_url = "https://terms.naver.com" + link
            detail_res = requests.get(detail_url, headers=headers)
            detail_soup = BeautifulSoup(detail_res.text, 'html.parser')
            time.sleep(1)  # 상세 페이지 요청 후 딜레이 추가
            
            # 개별 링크별 이미지 url 추출
            img_tag = detail_soup.find('img')
            if img_tag and img_tag.get('data-src'):
                img_url = img_tag.get('data-src')
                img_url_dict[food_name] = img_url
    
                # 이미지 다운로드
                urllib.request.urlretrieve(img_url, f"./{download_folder}/{food_name}.jpg")
                break                                 # img_url 발견 시 반복문 종료
    
        else:
            fail_list.append(food_name)

    return img_url_dict, fail_list

# %%
img_url_dict, fail_list = food_image_downloader(food_names, "food_image")
# Out:
# 이미지 다운로드 진행중: 100%|█████████████████| 552/552 [32:53<00:00,  3.57s/it]

# %%
img_url_dict.keys()
# Out:
# dict_keys(['고추잡채', '고추장볶음', '고추장아찌 무침', '고등어찌개', '고등어찜', '고등어튀김', '고디국(다슬기맑은국)', '고사리나물', '고등어구이', '고등어조림', '고구마튀김', '고기만두', '고구마밥', '고구마줄기나물', '계란빵', '고구마맛탕', '게맛살튀김', '게조림', '겨자채', '검정콩밥', '강낭콩밥', '건새우볶음', '감자탕', '감자튀김', '곰탕', '곤드레밥', '곤약조림', '골뱅이무침', '고추조림', '고추튀김', '고춧잎나물', '기장밥', '근대 된장국', '근대나물', '굴비구이', '굴전', '군만두', '굴 미역국', '굴국', '과일샐러드', '광어 매운탕', '김치볶음', '김치국', '김치만두', '김치 고기만두', '김치 돼지고기볶음', '김치 된장국', '김치 청국장찌개', '김치 콩나물국', '김밥', '김부각', '김말이튀김', '꽈리고추찜', '낙지 덮밥', '꽃게장', '꽃게탕', '꽈리고추볶음', '꽁치구이', '꽁치조림', '꽁치튀김', '꼬리곰탕', '꼬막찜', '깻잎장아찌', '깻잎전', '깻잎찜', '껍질콩볶음', '깻잎나물', '김치찜', '깐풍기', '김치찌개', '김치순두부', '김치전', '달걀부침(달걀후라이)', '달걀조림', '달걀찜', '달걀말이', '단호박조림', '달걀 샐러드', '달걀국', '다시마무침', '다시마튀각', '단무지무침', '느타리버섯볶음', '느타리버섯튀김', '녹두빈대떡', '냉이 된장국', '넙치구이', '노각무침', '난자완스', '낙지 비빔밥', '낙지볶음', '닭찜', '닭튀김', '닭죽', '닭도리탕', '닭백숙', '닭날개구이', '닭다리구이', '닭다리조림', '닭고기 탕수', '닭고기냉채', '닭고기육개장', '닭곰탕', '닭가슴살 샐러드', '닭강정', '닭고기 덮밥', '닭고기 샐러드', '달걀후라이', '달래무침', '대구 매운탕', '대구지리', '대구찜', '도토리묵무침', '돈가스', '도라지생채', '도루묵조림', '도라지나물', '된장국', '돼지사태찜', '돼지등심 장조림', '돼지머리국밥', '돼지불고기', '돼지고기볶음', '돼지고기찌개', '돼지고기 장조림', '돼지고기강정', '돼지갈비찜', '돼지고기 꼬치구이', '돼지고기 스테이크', '동태튀김', '돼지갈비구이', '동태전', '동태조림', '동태찌개', '동태찜', '돌나물', '돌나물무침', '돌솥 비빔밥', '동태 매운탕', '동태국', '떡국', '땅콩조림', '땅콩죽', '두부찌개', '두부튀김', '들깨국', '들깨죽', '두부전', '두부조림', '두부냉채', '두부볶음', '두부부침', '두부 된장국', '두부 청국장찌개', '두부국', '두부김치', '된장찌개', '두부 달걀찜', '떡볶이', '떡산적', '떡만두국', '런천미트구이', '라볶이', '마카로니 샐러드', '마늘쫑볶음', '마늘쫑장아찌무침', '마늘쫑무침', '멸치볶음', '멸치조림', '멕시컨샐러드', '멸치 미역국', '메밀묵국', '메추리알 돼지고기장조림', '메추리알 어묵조림', '메추리알장조림', '메밀묵 무침', '머위나물', '만두탕수', '망둥어찜', '매운 어묵볶음', '만두국', '마파두부', '미나리나물', '미나리무침', '미소된장국', '물만두', '미나리 초무침', '묵밥', '무생채', '무조림', '무생채(무만)', '무국', '무나물', '무말랭이무침', '무 어묵조림', '무 파래무침', '무 된장국', '모듬 초밥', '모듬배추나물', '모듬버섯볶음', '미트볼조림', '미역냉국', '미역줄기볶음', '미역초무침', '미역튀각', '미역국', '미역 오이무침', '배추 겉절이', '배추 된장국', '배추국', '바지락국', '바지락찜', '방풍나물', '바지락 미역국', '배추전', '배추나물', '버섯찌개', '버섯전', '버섯 매운탕', '볶음밥', '보리밥', '베이컨떡말이구이', '베이컨채소볶음', '병어조림', '비빔밥', '비름나물', '불낙전골', '브로콜리 두부무침', '브로콜리 버섯볶음', '북어국', '북어채 고추장 무침', '북어강정', '북어구이', '부추무침', '부추잡채', '부추전', '부추 겉절이', '부추김치', '부추나물', '뼈다귀해장국', '사골국', '새우탕', '새우튀김', '새우 탕수', '새우무침', '새우전', '새우젓국', '상추겉절이', '새송이버섯볶음', '새싹 샐러드', '삼치구이', '삼치조림', '삼치튀김', '상추 겉절이', '삼겹살볶음', '삼계탕', '삼색 오이냉국', '삼치 양념구이', '삶은 땅콩 조림', '삼각김밥', '소갈비찜', '소고기 국밥', '소고기 덮밥', '소고기 미역국', '선짓국', '설렁탕', '세발낙지볶음', '소갈비 구이', '섞어찌개(모듬찌개)', '생선까스', '샐러드', '소시지튀김', '소시지 케첩볶음', '소시지볶음', '소시지조림', '소불고기', '소사태찜', '소등심구이', '소라무침', '소고기채소볶음', '소등심 스테이크', '소고기볶음', '소고기육개장', '소고기찜', '소고기 완자전', '소고기 장조림', '순대볶음', '순대', '숙주나물', '숙주미나리나물', '수수밥', '스크램블드에그', '쑥갓나물', '쑥갓오이무침', '시금치나물', '시래기 된장국', '시래기나물', '시금치 겉절이', '시금치 된장국', '아귀 매운탕', '아귀찜', '아욱 된장국', '애호박 감자된장국', '애호박 된장국', '애호박나물', '알밥', '얼갈이겉절이', '어묵탕', '어묵튀김', '얼갈이 나물', '어묵잡채', '어묵조림', '어묵볶음', '어묵 감자볶음', '어묵 매운탕', '어묵 오이무침', '어묵국', '양송이버섯볶음', '양장피', '양파볶음', '양배추 샐러드', '양배추부추무침', '양상추 샐러드', '양념 오징어젓', '양미리조림', '양배추 겉절이', '양배추 사과 샐러드', '양념 돼지고기튀김', '애호박전', '애호박찌개', '애호박찜', '연근전', '연근조림', '연근튀김', '오징어볶음', '오징어불고기', '오징어 덮밥', '오징어국', '오징어무침', '오이생채', '오이소박이', '오이장아찌', '오이지무침', '오이나물', '오이냉국', '오이무침', '오이 도라지 생채', '오이 미역냉국', '오이고추 된장무침', '오이김치', '오리탕', '오므라이스', '오곡밥', '오리 간장불고기', '오리고기로스', '오리백숙', '열무나물', '영양돌솥밥', '연두부찜', '연어구이', '열무 비빔밥', '올갱이해장국', '옥수수밥', '옥수수부침', '옥수수샐러드', '오징어채볶음', '오징어튀김', '오징어조림', '오징어찌개', '오징어채무침', '유부 된장국', '유부 초밥', '유부조림', '우엉조림', '우럭구이', '우엉볶음', '완두콩밥', '완자전', '완자조림', '잔멸치볶음', '임연수구이', '임연수조림', '임연수튀김', '육개장', '유채나물', '유채무침', '조기찜', '조기튀김', '주먹밥', '조기 양념구이', '조기 오븐구이', '조기구이', '조기찌개', '제육볶음', '조개 미역국', '적어구이', '전복죽', '제육(돼지고기 수육)', '장조림', '재첩국', '장어 양념구이', '장어매운탕', '잡채밥', '잡곡밥', '잡채', '청포묵 무침', '청포묵무침', '채소튀김', '천사채무침', '청국장찌개', '채소밥', '채소전', '채소죽', '참치강정', '참치구이', '참치죽', '참치찌개', '참나물 겉절이', '참나물 무침', '참나물겉절이', '참치 미역국', '참치 샐러드', '참나물', '차조밥', '짬뽕밥', '짜장밥', '죽순볶음', '쥐포무침', '쥐포조림', '치커리 겉절이', '치커리겉절이', '취나물무침', '추어탕', '취나물', '카레라이스', '콩나물국', '콩나물 느타리무침', '콩나물 된장국', '콩나물 선짓국', '콩나물 황태국', '콘치즈구이', '콩나물 국밥', '코다리조림', '코다리찜', '콩조림', '콩나물밥', '콩나물잡채', '콩비지찌개', '콩나물무침', '콩나물냉채 ...

# %%
len(fail_list)
# Out:
# 37

# %%
img_url_dict2, fail_list2 = food_image_downloader(fail_list, 'food_image')
# Out:
# 이미지 다운로드 진행중: 100%|███████████████████| 37/37 [02:30<00:00,  4.08s/it]

# %%
img_url_dict2
# Out:
# {'낙지무침': 'https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2756_000_1%2F20131109034544516_KRUWW68C0.jpg%2Fck_787_i1.jpg%3Ftype%3Dw690_fst_n%26wm%3DY%22&twidth=431&theight=530&opts=17',
#  '닭구이': 'https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2756_000_1%2F20131109064000713_UQ0DLTQT6.jpg%2Finst_126_i1.jpg%3Ftype%3Dw690_fst_n%26wm%3DY%22&twidth=397&theight=530&opts=17',
#  '무 북어국': 'https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5557_000_1%2F20180912120729440_VBS8HDCYT.jpg%2Ffe96_64_i1.jpg%3Ftype%3Dw690_fst_n%26wm%3DY%22&twidth=470&theight=530&opts=17',
#  '부대찌개': 'https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F5671_000_1%2F20181123154211812_QFU8GJGSW.jpg%2Ffe119_26_i1.jpg%3Ftype%3Dw690_fst_n%26wm%3DY%22&twidth=375&theight=519&opts=17',
#  '브로콜리무침': 'https://dthumb-phinf.pstatic.net/?src=%22https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2756_000_1%2F20131109032322894_WEZEUABU3.jpg%2Fck_437_i1.jpg%3Ftype%3Dw690_fst_n%26wm%3DY%22&twidth=430&theight=530&opts=17'}

# %%
fail_list2
# Out:
# ['건새우 미역국',
#  '깻잎김치',
#  '냉이초나물',
#  '닭튀김 샐러드',
#  '닭볶음(닭갈비)',
#  '닭조림',
#  '닭고기 미역국',
#  '대합 미역국',
#  '대합죽',
#  '맛살전',
#  '버섯국',
#  '삼색냉채',
#  '소고기 두부국',
#  '소고기 샌드위치',
#  '순대국',
#  '쑥튀김',
#  '얼갈이 된장국',
#  '어묵국(어묵탕)',
#  '양배추 초나물',
#  '애호박부침개',
#  '열무 된장국',
#  '오징어탕수',
#  '율무밥',
#  '조미 김구이',
#  '잡곡죽',
#  '짜사이무침',
#  '치킨데리야끼',
#  '감자 된장국',
#  '감자국',
#  '해물 된장국',
#  '햄부침',
#  '홍합 무국']

# %%
# 올바르지 않은 이미지가 추출된 food_list
fail_foods = [
    "두부국", "소등심 스테이크", "임연수튀김", "채소전", "참치구이", "참치강정", "짬뽕밥", "짜장밥", "쥐포무침",
    "탕수어", "탕수육", "가자미매운탕", "가자미구이", "가자미찜", "감자연근튀김", "햄구이", "혼합잡곡밥",
    "치커리겉절이", "오리고기로스", "양배추 샐러드", "양배추 사과 샐러드", "양배추 겉절이", "양배추부추무침",
    "어묵 오이무침", "얼갈이 나물", "청포묵 무침", "적어구이", "유채나물", "우럭구이", "어묵 매운탕",
    "어묵 감자볶음", "어묵잡채", "어묵탕", "숙주미나리나물", "생선까스", "세발낙지볶음", "상추 겉절이",
    "무생채(무만)", "망둥어찜", "메밀묵국", "돼지머리국밥", "돼지등심 장조림", "돼지사태찜", "돼지고기 스테이크",
    "넙치구이", "강낭콩밥", "아귀 매운탕", "소등심구이", "소사태찜", "소불고기", "마카로니 샐러드", "김치 된장국",
    "치커리 겉절이"
]

# %%
fail_foods = fail_foods + fail_list2
fail_foods
# Out:
# ['두부국',
#  '소등심스테이크',
#  '임연수튀김',
#  '채소전',
#  '참치구이',
#  '참치강정',
#  '짬뽕밥',
#  '짜장밥',
#  '쥐포무침',
#  '탕수어',
#  '탕수육',
#  '가자미매운탕',
#  '가자미구이',
#  '가자미찜',
#  '감자연근튀김',
#  '햄구이',
#  '혼합잡곡밥',
#  '치커리겉절이',
#  '건새우 미역국',
#  '깻잎김치',
#  '냉이초나물',
#  '닭튀김 샐러드',
#  '닭볶음(닭갈비)',
#  '닭조림',
#  '닭고기 미역국',
#  '대합 미역국',
#  '대합죽',
#  '맛살전',
#  '버섯국',
#  '삼색냉채',
#  '소고기 두부국',
#  '소고기 샌드위치',
#  '순대국',
#  '쑥튀김',
#  '얼갈이 된장국',
#  '어묵국(어묵탕)',
#  '양배추 초나물',
#  '애호박부침개',
#  '열무 된장국',
#  '오징어탕수',
#  '율무밥',
#  '조미 김구이',
#  '잡곡죽',
#  '짜사이무침',
#  '치킨데리야끼',
#  '감자 된장국',
#  '감자국',
#  '해물 된장국',
#  '햄부침',
#  '홍합 무국']

# %% [markdown]
# # 추출 실패한 음식 이미지 OpenAI로 생성하기

# %%
fail_foods = [
    "두부국", "소등심 스테이크", "임연수튀김", "채소전", "참치구이", "참치강정", "짬뽕밥", "짜장밥", "쥐포무침",
    "탕수어", "탕수육", "가자미매운탕", "가자미구이", "가자미찜", "감자연근튀김", "햄구이", "혼합잡곡밥",
    "치커리겉절이", "오리고기로스", "양배추 샐러드", "양배추 사과 샐러드", "양배추 겉절이", "양배추부추무침",
    "어묵 오이무침", "얼갈이 나물", "청포묵 무침", "적어구이", "유채나물", "우럭구이", "어묵 매운탕",
    "어묵 감자볶음", "어묵잡채", "어묵탕", "숙주미나리나물", "생선까스", "세발낙지볶음", "상추 겉절이",
    "무생채(무만)", "망둥어찜", "메밀묵국", "돼지머리국밥", "돼지등심 장조림", "돼지사태찜", "돼지고기 스테이크",
    "넙치구이", "강낭콩밥", "아귀 매운탕", "소등심구이", "소사태찜", "소불고기", "마카로니 샐러드", "김치 된장국",
    "치커리 겉절이", "건새우 미역국", "깻잎김치", "냉이초나물", "닭튀김 샐러드", "닭볶음(닭갈비)", "닭조림", "닭고기 미역국",
    "대합 미역국", "대합죽", "맛살전", "버섯국", "삼색냉채", "소고기 두부국", "소고기 샌드위치", "순대국",
    "쑥튀김", "얼갈이 된장국", "어묵국(어묵탕)", "양배추 초나물", "애호박부침개", "열무 된장국", "오징어탕수",
    "율무밥", "조미 김구이", "잡곡죽", "짜사이무침", "치킨데리야끼", "감자 된장국", "감자국", "해물 된장국",
    "햄부침", "홍합 무국"
]

# %%
len(fail_foods)
# Out:
# 85

# %%
import openai
import requests

# %%
# API 키 설정 (안전한 관리 필요)
openai.api_key = '...'

# %%
# 각 음식에 대해 이미지 생성 및 저장
for food in fail_foods:
    # 음식명에 맞는 실제 사진과 같은 이미지 생성 프롬프트
    prompt = (
        f"{food}, 실사 스타일, 고화질 음식 사진, "
        "자연광 조명, 전통적인 한식 느낌, 조리된 상태로 "
        "세라믹 접시에 플레이팅 되어 테이블 위에 놓여있는 모습"
    )
    
    # 이미지 생성 요청
    response = openai.Image.create(
        model="dall-e-3",
        prompt=prompt,
        n=1,                             # 생성할 이미지 개수
        size="1024x1024"                 # 이미지 크기 (필요에 따라 변경)
    )
    
    # 생성된 이미지 URL 추출
    image_url = response['data'][0]['url']
    
    # # 이미지 다운로드
    # image_data = requests.get(image_url).content
    
    # # 로컬 파일로 이미지 저장
    # with open(f'./food/{food}.jpg', "wb") as f:
    #     f.write(image_data)
    
    # print(f"{food} 저장 완료!")
    print(f"{food} : {image_url}")
# Out:
# 두부국 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-RInnhMVM2L4C1J6mw8a5dkke.png?st=2025-04-02T06%3A26%3A35Z&se=2025-04-02T08%3A26%3A35Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T17%3A26%3A59Z&ske=2025-04-02T17%3A26%3A59Z&sks=b&skv=2024-08-04&sig=Tp0vsYWVzDxNfc4a3o6fGXdWpubNKvOKet8BTFIPIvY%3D
# 소등심스테이크 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-OGCoMbdtS53WsOyAYjUqZCio.png?st=2025-04-02T06%3A26%3A47Z&se=2025-04-02T08%3A26%3A47Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T20%3A33%3A02Z&ske=2025-04-02T20%3A33%3A02Z&sks=b&skv=2024-08-04&sig=ioQnaLUx9vMYks0XPsKekqdNlZqLu31zdo06TYGPynM%3D
# 임연수튀김 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-gqvVbxurF0QyHDqPvBuC8IKU.png?st=2025-04-02T06%3A26%3A59Z&se=2025-04-02T08%3A26%3A59Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T17%3A34%3A18Z&ske=2025-04-02T17%3A34%3A18Z&sks=b&skv=2024-08-04&sig=H1boZ2z%2BQsc6ul0MDw6wBgxpiiFJb%2BDR%2BID5vakJLsQ%3D
# 채소전 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-Undk4fBsAY4YHc3yLrLNpMHq.png?st=2025-04-02T06%3A27%3A12Z&se=2025-04-02T08%3A27%3A12Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T10%3A54%3A28Z&ske=2025-04-02T10%3A54%3A28Z&sks=b&skv=2024-08-04&sig=19ZwR1zZPcGFkHGjTbRMt2/XD3yCId8SID3ClD5G1HI%3D
# 참치구이 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-i1sq8jmEhl1AZvNchMWNkLVP.png?st=2025-04-02T06%3A27%3A22Z&se=2025-04-02T08%3A27%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T15%3A14%3A13Z&ske=2025-04-02T15%3A14%3A13Z&sks=b&skv=2024-08-04&sig=9Gk5oj3njjoj/pCw/2Vyx/493Hl/UCHMDA93x1Gfrj0%3D
# 참치강정 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-kEXAKcRF9SfVhni1D42aKMNa.png?st=2025-04-02T06%3A27%3A36Z&se=2025-04-02T08%3A27%3A36Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-02T05%3A48%3A41Z&ske=2025-04-03T05%3A48%3A41Z&sks=b&skv=2024-08-04&sig=msxyqwehhcIMfSIMc35EoGHnEluf%2BeJKET9vLpx5OuM%3D
# 짬뽕밥 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-nOjkZbUoHNZVtO5sr4SP4jVz.png?st=2025-04-02T06%3A27%3A52Z&se=2025-04-02T08%3A27%3A52Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T11%3A49%3A10Z&ske=2025-04-02T11%3A49%3A10Z&sks=b&skv=2024-08-04&sig=USfL5NZH2oDNzIOOYmv3liQucA1LJDL%2BVIy4yZpgVTU%3D
# 짜장밥 : https://oaidalleapiprodscus.blob.core.windows.net/private/org-cusAGD44UGtGz07NkhY7ioiy/user-I7BqbEKBLSQ8xZfa7YQd3dTW/img-NFX8drkBsi6gN56VpEsLQPry.png?st=2025-04-02T06%3A28%3A04Z&se=2025-04-02T08%3A28%3A04Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-04-01T20%3A23%3A07Z&ske=2025-04-02T20%3A23%3A07Z&sks=b&skv=2024-08-04&sig=iuGNOqWQflclzJGkh4IiOV9iO6TI8EjzWWrwY7%2BZTJ8%3D
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 11
#       4 prompt = (
#       5     f"{food}, 실사 스타일, 고화질 음식 사진, "
#       6     "자연광 조명, 전통적인 한식 느낌, 조리된 상태로 "
#       7     "세라믹 접시에 플레이팅 되어 테이블 위에 놓여있는 모습"
#       8 )
#      10 # 이미지 생성 요청
# ---> 11 response = openai.Image.create(
#      12     model="dall-e-3",
#      13     prompt=prompt,
#      14     n=1,                             # 생성할 이미지 개수
#      15     size="1024x1024"                 # 이미지 크기 (필요에 따라 변경)
#      16 )
#      18 # 생성된 이미지 URL 추출
#      19 image_url = response['data'][0]['url']
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/api_resources/image.py:39, in Image.create(cls, api_key, api_base, api_type, api_version, organization, **params)
#      29 requestor = api_requestor.APIRequestor(
#      30     api_key,
#      31     api_base=api_base or openai.api_base,
#    (...)
#      34     organization=organization,
#      35 )
#      37 api_type, api_version = cls._get_api_type_and_version(api_type, api_version)
# ---> 39 response, _, api_key = requestor.request(
#      40     "post", cls._get_url("generations", azure_action="submit", api_type=api_type, api_version=api_version), params
#      41 )
#      43 if api_type in (util.ApiType.AZURE, util.ApiType.AZURE_AD):
#      44     requestor.api_base = "" # operation_location is a full url
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
